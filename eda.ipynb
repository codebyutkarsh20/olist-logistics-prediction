# %% [markdown]
# # 🇧🇷 Olist E-Commerce: Detailed Data Inspection
#
# ## 🎯 Objective
# The goal of this notebook is to inspect **every single CSV file** in the Olist dataset to understand its "gotext" (context), schema, and relationships. This foundation is crucial for building robust ML models.
#
# ## 📂 Dataset Overview
# The dataset consists of 9 files:
# 1.  `olist_orders_dataset.csv`: The core table connecting everything.
# 2.  `olist_order_items_dataset.csv`: Details of products within orders.
# 3.  `olist_order_payments_dataset.csv`: Payment methods and values.
# 4.  `olist_order_reviews_dataset.csv`: Customer satisfaction scores.
# 5.  `olist_customers_dataset.csv`: Customer IDs and geolocations.
# 6.  `olist_products_dataset.csv`: Product categories and dimensions.
# 7.  `olist_sellers_dataset.csv`: Seller information.
# 8.  `olist_geolocation_dataset.csv`: Lat/Lng for zip codes.
# 9.  `product_category_name_translation.csv`: Portuguese to English translations.

# %%
import pandas as pd
import os

# Config
DATA_DIR = "olist_data"

def inspect_csv(filename, description):
    path = os.path.join(DATA_DIR, filename)
    print(f"\n{'='*80}\n📂 INSPECTING: {filename}\n{'='*80}")
    print(f"ℹ️ CONTEXT: {description}\n")
    
    try:
        df = pd.read_csv(path)
        print(f"Shape: {df.shape} (Rows, Cols)")
        print("\n--- 📋 Columns & Data Types ---")
        print(df.dtypes)
        print("\n--- 🔍 Head (First 3 Rows) ---")
        display(df.head(3))
        print("\n--- 📉 Basic Stats ---")
        display(df.describe(include='all').T.iloc[:, :7]) # Transposed for readability
        return df
    except Exception as e:
        print(f"❌ Error loading {filename}: {e}")
        return None

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Orders Dataset (`olist_orders_dataset.csv`)
# **Context:** This is the "parent" table. Every order has a unique `order_id`. It connects customers to the items they bought. Key columns are the timestamps (purchase, approval, carrier delivery, customer delivery, estimated delivery) and the `order_status`.

# %%
df_orders = inspect_csv(
    "olist_orders_dataset.csv",
    "Central table connecting all other datasets. Tracks the life-cycle of an order."
)
# Out:
# ================================================================================
# 📂 INSPECTING: olist_orders_dataset.csv
# ================================================================================
# ℹ️ CONTEXT: Central table connecting all other datasets. Tracks the life-cycle of an order.
#
# Shape: (99441, 8) (Rows, Cols)
#
# --- 📋 Columns & Data Types ---
# order_id                         str
# customer_id                      str
# order_status                     str
# order_purchase_timestamp         str
# order_approved_at                str
# order_delivered_carrier_date     str
# order_delivered_customer_date    str
# order_estimated_delivery_date    str
# dtype: object
#
# --- 🔍 Head (First 3 Rows) ---
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# --- 📉 Basic Stats ---
#                                count unique                               top  \
# order_id                       99441  99441  e481f51cbdc54678b7cc49136f2d6af7
# customer_id                    99441  99441  9ef432eb6251297304e76186b10a928d
# order_status                   99441      8                         delivered
# order_purchase_timestamp       99441  98875               2018-03-31 15:08:21
# order_approved_at              99281  90733               2018-02-27 04:31:10
# order_delivered_carrier_date   97658  81018               2018-05-09 15:48:00
# order_delivered_customer_date  96476  95664               2018-05-14 20:02:44
# order_estimated_delivery_date  99441    459               2017-12-20 00:00:00
#
#                                 freq
# order_id                           1
# customer_id                        1
# order_status                   96478
# order_purchase_timestamp           3
# order_approved_at                  9
# order_delivered_carrier_date      47
# order_delivered_customer_date      3
# order_estimated_delivery_date    522

# %% [markdown]
# ## 2. Order Items Dataset (`olist_order_items_dataset.csv`)
# **Context:** A single order can contain multiple items. This table links `order_id` to `product_id` and `seller_id`. It provides the `price` and `freight_value` for each item. This is essential for revenue analysis.

# %%
df_items = inspect_csv(
    "olist_order_items_dataset.csv",
    "Contains the individual items (SKUs) within each order. Links orders to products and sellers."
)
# Out:
# ================================================================================
# 📂 INSPECTING: olist_order_items_dataset.csv
# ================================================================================
# ℹ️ CONTEXT: Contains the individual items (SKUs) within each order. Links orders to products and sellers.
#
# Shape: (112650, 7) (Rows, Cols)
#
# --- 📋 Columns & Data Types ---
# order_id                   str
# order_item_id            int64
# product_id                 str
# seller_id                  str
# shipping_limit_date        str
# price                  float64
# freight_value          float64
# dtype: object
#
# --- 🔍 Head (First 3 Rows) ---
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
#
#    shipping_limit_date  price  freight_value
# 0  2017-09-19 09:45:35   58.9          13.29
# 1  2017-05-03 11:05:13  239.9          19.93
# 2  2018-01-18 14:48:30  199.0          17.87
# --- 📉 Basic Stats ---
#                         count unique                               top  freq  \
# order_id               112650  98666  8272b63d03f5f79c56e9e4120aec44ef    21
# order_item_id        112650.0    NaN                               NaN   NaN
# product_id             112650  32951  aca2eb7d00ea1a7b8ebd4e68314663af   527
# seller_id              112650   3095  6560211a19b47992c3666cc44a7e94c0  2033
# shipping_limit_date    112650  93318               2018-03-01 02:50:48    21
# price                112650.0    NaN                               NaN   NaN
# freight_value        112650.0    NaN                               NaN   NaN
#
#                            mean         std   min
# order_id                    NaN         NaN   NaN
# order_item_id          1.197834    0.705124   1.0
# product_id                  NaN         NaN   NaN
# seller_id                   NaN         NaN   NaN
# shipping_limit_date         NaN         NaN   NaN
# price                120.653739  183.633928  0.85
# freight_value          19.99032   15.806405   0.0

# %% [markdown]
# ## 3. Order Payments Dataset (`olist_order_payments_dataset.csv`)
# **Context:** Shows how the order was paid (Credit Card, Boleto, Voucher, etc.) and the payment value. An order can have multiple payment methods (sequential) or installments.

# %%
df_payments = inspect_csv(
    "olist_order_payments_dataset.csv",
    "Financial data: payment types (credit card, voucher), installments, and transaction values."
)
# Out:
# ================================================================================
# 📂 INSPECTING: olist_order_payments_dataset.csv
# ================================================================================
# ℹ️ CONTEXT: Financial data: payment types (credit card, voucher), installments, and transaction values.
#
# Shape: (103886, 5) (Rows, Cols)
#
# --- 📋 Columns & Data Types ---
# order_id                    str
# payment_sequential        int64
# payment_type                str
# payment_installments      int64
# payment_value           float64
# dtype: object
#
# --- 🔍 Head (First 3 Rows) ---
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# --- 📉 Basic Stats ---
#                          count unique                               top  \
# order_id                103886  99440  fa65dad1b0e818e3ccc5cb0e39231352
# payment_sequential    103886.0    NaN                               NaN
# payment_type            103886      5                       credit_card
# payment_installments  103886.0    NaN                               NaN
# payment_value         103886.0    NaN                               NaN
#
#                        freq       mean         std  min
# order_id                 29        NaN         NaN  NaN
# payment_sequential      NaN   1.092679    0.706584  1.0
# payment_type          76795        NaN         NaN  NaN
# payment_installments    NaN   2.853349    2.687051  0.0
# payment_value           NaN  154.10038  217.494064  0.0

# %% [markdown]
# ## 4. Order Reviews Dataset (`olist_order_reviews_dataset.csv`)
# **Context:** The voice of the customer. Includes `review_score` (1-5) and text comments (`review_comment_message`). Crucial for Sentiment Analysis or measuring Customer Satisfaction (CSAT).

# %%
df_reviews = inspect_csv(
    "olist_order_reviews_dataset.csv",
    "Customer feedback: ratings (1-5) and free-text comments written by customers."
)
# Out:
# ================================================================================
# 📂 INSPECTING: olist_order_reviews_dataset.csv
# ================================================================================
# ℹ️ CONTEXT: Customer feedback: ratings (1-5) and free-text comments written by customers.
#
# Shape: (99224, 7) (Rows, Cols)
#
# --- 📋 Columns & Data Types ---
# review_id                    str
# order_id                     str
# review_score               int64
# review_comment_title         str
# review_comment_message       str
# review_creation_date         str
# review_answer_timestamp      str
# dtype: object
#
# --- 🔍 Head (First 3 Rows) ---
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
#
#    review_score review_comment_title review_comment_message  \
# 0             4                  NaN                    NaN
# 1             5                  NaN                    NaN
# 2             5                  NaN                    NaN
#
#   review_creation_date review_answer_timestamp
# 0  2018-01-18 00:00:00     2018-01-18 21:46:59
# 1  2018-03-10 00:00:00     2018-03-11 03:05:13
# 2  2018-02-17 00:00:00     2018-02-18 14:36:24
# --- 📉 Basic Stats ---
#                            count unique                               top  \
# review_id                  99224  98410  c444278834184f72b1484dfe47de7f97
# order_id                   99224  98673  c88b1d1b157a9999ce368f218a407141
# review_score             99224.0    NaN                               NaN
# review_comment_title       11568   4527                         Recomendo
# review_comment_message     40977  36159                         Muito bom
# review_creation_date       99224    636               2017-12-19 00:00:00
# review_answer_timestamp    99224  98248               2017-06-15 23:21:05
#
#                         freq      mean       std  min
# review_id                  3       NaN       NaN  NaN
# order_id                   3       NaN       NaN  NaN
# review_score             NaN  4.086421  1.347579  1.0
# review_comment_title     423       NaN       NaN  NaN
# review_comment_message   230       NaN       NaN  NaN
# review_creation_date     463       NaN       NaN  NaN
# review_answer_timestamp    4       NaN       NaN  NaN

# %% [markdown]
# ## 5. Customers Dataset (`olist_customers_dataset.csv`)
# **Context:** Contains customer location data (zip code, city, state). **Important:** It maps `customer_id` (used in Orders table) to `customer_unique_id` (the distinct real human). If a person orders twice, they get 2 `customer_id`s but keep 1 `customer_unique_id`.

# %%
df_customers = inspect_csv(
    "olist_customers_dataset.csv",
    "Demographics: Links order-specific 'customer_id' to persistent 'customer_unique_id' and location."
)
# Out:
# ================================================================================
# 📂 INSPECTING: olist_customers_dataset.csv
# ================================================================================
# ℹ️ CONTEXT: Demographics: Links order-specific 'customer_id' to persistent 'customer_unique_id' and location.
#
# Shape: (99441, 5) (Rows, Cols)
#
# --- 📋 Columns & Data Types ---
# customer_id                   str
# customer_unique_id            str
# customer_zip_code_prefix    int64
# customer_city                 str
# customer_state                str
# dtype: object
#
# --- 🔍 Head (First 3 Rows) ---
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# --- 📉 Basic Stats ---
#                             count unique                               top  \
# customer_id                 99441  99441  06b8999e2fba1a1fbc88172c00ba8bc7
# customer_unique_id          99441  96096  8d50f5eadf50201ccdcedfb9e2ac8455
# customer_zip_code_prefix  99441.0    NaN                               NaN
# customer_city               99441   4119                         sao paulo
# customer_state              99441     27                                SP
#
#                            freq          mean           std     min
# customer_id                   1           NaN           NaN     NaN
# customer_unique_id           17           NaN           NaN     NaN
# customer_zip_code_prefix    NaN  35137.474583  29797.938996  1003.0
# customer_city             15540           NaN           NaN     NaN
# customer_state            41746           NaN           NaN     NaN

# %% [markdown]
# ## 6. Products Dataset (`olist_products_dataset.csv`)
# **Context:** Attributes of the goods sold: category name, weight, and dimensions (L x W x H). Essential for freight calculation analysis.

# %%
df_products = inspect_csv(
    "olist_products_dataset.csv",
    "Catalog info: Category names, product weight, and dimensions."
)
# Out:
# ================================================================================
# 📂 INSPECTING: olist_products_dataset.csv
# ================================================================================
# ℹ️ CONTEXT: Catalog info: Category names, product weight, and dimensions.
#
# Shape: (32951, 9) (Rows, Cols)
#
# --- 📋 Columns & Data Types ---
# product_id                        str
# product_category_name             str
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object
#
# --- 🔍 Head (First 3 Rows) ---
#                          product_id product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5            perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                 artes
# 2  96bd76ec8810374ed1b65e291975717f         esporte_lazer
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# --- 📉 Basic Stats ---
#                               count unique                               top  \
# product_id                    32951  32951  1e9e8ef04dbcff4541ed26657ea517e5
# product_category_name         32341     73                   cama_mesa_banho
# product_name_lenght         32341.0    NaN                               NaN
# product_description_lenght  32341.0    NaN                               NaN
# product_photos_qty          32341.0    NaN                               NaN
# product_weight_g            32949.0    NaN                               NaN
# product_length_cm           32949.0    NaN                               NaN
# product_height_cm           32949.0    NaN                               NaN
# product_width_cm            32949.0    NaN                               NaN
#
#                             freq         mean          std  min
# product_id                     1          NaN          NaN  NaN
# product_category_name       3029          NaN          NaN  NaN
# product_name_lenght          NaN    48.476949    10.245741  5.0
# product_description_lenght   NaN   771.495285   635.115225  4.0
# product_photos_qty           NaN     2.188986     1.736766  1.0
# product_weight_g             NaN  2276.472488  4282.038731  0.0
# product_length_cm            NaN    30.815078    16.914458  7.0
# product_height_cm            NaN    16.937661    13.637554  2.0
# product_width_cm             NaN    23.196728    12.079047  6.0

# %% [markdown]
# ## 7. Sellers Dataset (`olist_sellers_dataset.csv`)
# **Context:** Location of the merchants fulfilling orders. Combined with customer location, this allows calculating distance.

# %%
df_sellers = inspect_csv(
    "olist_sellers_dataset.csv",
    "Merchant info: Seller zip codes, cities, and states."
)
# Out:
# ================================================================================
# 📂 INSPECTING: olist_sellers_dataset.csv
# ================================================================================
# ℹ️ CONTEXT: Merchant info: Seller zip codes, cities, and states.
#
# Shape: (3095, 4) (Rows, Cols)
#
# --- 📋 Columns & Data Types ---
# seller_id                   str
# seller_zip_code_prefix    int64
# seller_city                 str
# seller_state                str
# dtype: object
#
# --- 🔍 Head (First 3 Rows) ---
#                           seller_id  seller_zip_code_prefix     seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023        campinas
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844      mogi guacu
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031  rio de janeiro
#
#   seller_state
# 0           SP
# 1           SP
# 2           RJ
# --- 📉 Basic Stats ---
#                          count unique                               top  freq  \
# seller_id                 3095   3095  3442f8959a84dea7ee197c632cb2df15     1
# seller_zip_code_prefix  3095.0    NaN                               NaN   NaN
# seller_city               3095    611                         sao paulo   694
# seller_state              3095     23                                SP  1849
#
#                                 mean          std     min
# seller_id                        NaN          NaN     NaN
# seller_zip_code_prefix  32291.059451  32713.45383  1001.0
# seller_city                      NaN          NaN     NaN
# seller_state                     NaN          NaN     NaN

# %% [markdown]
# ## 8. Geolocation Dataset (`olist_geolocation_dataset.csv`)
# **Context:** A mapping of Brazilian zip codes (`geolocation_zip_code_prefix`) to Latitude/Longitude coordinates. Allows visualizing data on a map.

# %%
df_geo = inspect_csv(
    "olist_geolocation_dataset.csv",
    "Geospatial data: Mapping zip codes to Lat/Lng coordinates."
)
# Out:
# ================================================================================
# 📂 INSPECTING: olist_geolocation_dataset.csv
# ================================================================================
# ℹ️ CONTEXT: Geospatial data: Mapping zip codes to Lat/Lng coordinates.
#
# Shape: (1000163, 5) (Rows, Cols)
#
# --- 📋 Columns & Data Types ---
# geolocation_zip_code_prefix      int64
# geolocation_lat                float64
# geolocation_lng                float64
# geolocation_city                   str
# geolocation_state                  str
# dtype: object
#
# --- 🔍 Head (First 3 Rows) ---
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# --- 📉 Basic Stats ---
#                                  count unique        top    freq  \
# geolocation_zip_code_prefix  1000163.0    NaN        NaN     NaN
# geolocation_lat              1000163.0    NaN        NaN     NaN
# geolocation_lng              1000163.0    NaN        NaN     NaN
# geolocation_city               1000163   8011  sao paulo  135800
# geolocation_state              1000163     27         SP  404268
#
#                                      mean          std         min
# geolocation_zip_code_prefix  36574.166466  30549.33571      1001.0
# geolocation_lat                -21.176153     5.715866  -36.605374
# geolocation_lng                -46.390541     4.269748 -101.466766
# geolocation_city                      NaN          NaN         NaN
# geolocation_state                     NaN          NaN         NaN

# %% [markdown]
# ## 9. Category Translation (`product_category_name_translation.csv`)
# **Context:** Helper table to translate Portuguese category names to English.

# %%
df_trans = inspect_csv(
    "product_category_name_translation.csv",
    "Translation Map: product_category_name (PT) -> product_category_name_english (EN)"
)
# Out:
# ================================================================================
# 📂 INSPECTING: product_category_name_translation.csv
# ================================================================================
# ℹ️ CONTEXT: Translation Map: product_category_name (PT) -> product_category_name_english (EN)
#
# Shape: (71, 2) (Rows, Cols)
#
# --- 📋 Columns & Data Types ---
# product_category_name            str
# product_category_name_english    str
# dtype: object
#
# --- 🔍 Head (First 3 Rows) ---
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# --- 📉 Basic Stats ---
#                               count unique            top freq
# product_category_name            71     71   beleza_saude    1
# product_category_name_english    71     71  health_beauty    1
